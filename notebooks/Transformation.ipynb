# %% [markdown]
# # Crop Statistics – Group Project
#
# **Course:**Data Mastery
# **University:** University of Twente – ITC
# **Group members:**
#
# Pleun Kuipers
# Ethan Höfgen
# Ishraque Bin Khalil
# Kilian O'Donell
# ---
#
# ## 1. Goal
# Reproduction of Estimating Crop Area Statistics for Gaza Province, Mozambique Using Earth
# Observation and Field Data
#
# ## 2. Data
# Where the data comes from.
#
# ## 3. Method
# What you calculate.
#
# ## 4. Results
# Plots / tables.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Notebook works")
# Out:
# Notebook works
